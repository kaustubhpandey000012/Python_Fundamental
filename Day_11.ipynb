# %%
    #Create a tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

root = Node(10)

root.left = Node(20)
root.right = Node(30)

root.left.left = Node(40)
root.left.right = Node(50)

print("Root: ", root.data)
print("Left Child: ", root.left.data)
print("Right Child: ", root.right.data)
# Out:
# Root:  10
# Left Child:  20
# Right Child:  30

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)
        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)

        return root

    def inorder(self, root):
        if root:
            self.inorder(root.left)
            print(root.data, end=" ")
            self.inorder(root.right)

    def find_min(self, root):
        while root.left:
            root = root.left
        return root

    def delete(self, root, data):
        if root is None:
            return root

        if data < root.data:
            root.left = self.delete(root.left, data)

        elif data > root.data:
            root.right = self.delete(root.right, data)

        else:

            if root.left is None and root.right is None:
                return None

            if root.left is None:
                return root.right

            if root.right is None:
                return root.left

            successor = self.find_min(root.right)
            root.data = successor.data
            root.right = self.delete(root.right, successor.data)

        return root

bst = BST()

values = [50, 30, 70, 20, 40, 60, 80]

for value in values:
    bst.root = bst.insert(bst.root, value)

print("Before deletion: ")
bst.inorder(bst.root)

bst.root = bst.delete(bst.root, 20)

print("\nAfter deleting 20: ")
bst.inorder(bst.root)

bst.root = bst.delete(bst.root, 50)

print("\nAfter deleting 50: ")
bst.inorder(bst.root)
# Out:
# Before deletion:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 65
#      62     bst.root = bst.insert(bst.root, value)
#      64 print("Before deletion: ")
# ---> 65 bst.inorder(bst.root)
#      67 bst.root = bst.delete(bst.root, 20)
#      69 print("\nAfter deleting 20: ")
#
# Cell In[5], line 21, in BST.inorder(self, root)
#      19 def inorder(self, root):
#      20     if root:
# ---> 21         self.inorder(self, root)
#      22         print(root.data, end=" ")
#      23         self.inorder(root.right)
#
# TypeError: BST.inorder() takes 2 positional arguments but 3 were given
